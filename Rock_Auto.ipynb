# %%
import requests, re, os, json
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
base_url = 'https://www.rockauto.com/'
act_req = requests.Session()
r1 = act_req.get("https://www.rockauto.com/en/catalog/")
soup = BeautifulSoup(r1.text, 'html.parser')

# %%
tags = soup.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})

# %%
random=[]
for x in tags:
    temp=x.find('tr')
    random.append(temp)

# %%
len(random)
# Out:
# 262

# %% [markdown]
# ### For front page  - 1

# %%
data_orig1 = []
for y in random:
    data1={}
    
    chck = y.find('a', {'class': 'navlabellink nvoffset nnormal'})
    if chck == None:
        chck = y.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data1['name'] = 'important'
    #global url_1
    url_1 = urljoin(base_url, chck.get('href'))
    
    
    
    
    flg = y.find('td', {'class': 'rc nflags'})
    flags_1 = [d.get('aria-label').replace('flag', '').split('the')[-1].strip()for d in flg.findAll('a')]
    
    name_1 = chck.text
    data1["name"] = name_1
    data1["url"] = url_1
    
    data1['flags'] = flags_1
    
    
    data_orig1.append(data1)
data_orig1
# Out:
# [{'name': 'ABARTH',
#   'url': 'https://www.rockauto.com/en/catalog/abarth',
#   'flags': ['USA']},
#  {'name': 'AC',
#   'url': 'https://www.rockauto.com/en/catalog/ac',
#   'flags': ['USA']},
#  {'name': 'ACURA',
#   'url': 'https://www.rockauto.com/en/catalog/acura',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'ALFA ROMEO',
#   'url': 'https://www.rockauto.com/en/catalog/alfa+romeo',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'ALLARD',
#   'url': 'https://www.rockauto.com/en/catalog/allard',
#   'flags': ['USA']},
#  {'name': 'ALLSTATE',
#   'url': 'https://www.rockauto.com/en/catalog/allstate',
#   'flags': ['USA']},
#  {'name': 'ALPINE',
#   'url': 'https://www.rockauto.com/en/catalog/alpine',
#   'flags': ['USA']},
#  {'name': 'ALVIS',
#   'url': 'https://www.rockauto.com/en/catalog/alvis',
#   'flags': ['USA']},
#  {'name': 'AM GENERAL',
#   'url': 'https://www.rockauto.com/en/catalog/am+general',
#   'flags': ['USA']},
#  {'name': 'AMERICAN AUSTIN',
#   'url': 'https://www.rockauto.com/en/catalog/american+austin',
#   'flags': ['USA']},
#  {'name': 'AMERICAN BANTAM',
#   'url': 'https://www.rockauto.com/en/catalog/american+bantam',
#   'flags': ['USA']},
#  {'name': 'AMERICAN MOTORS',
#   'url': 'https://www.rockauto.com/en/catalog/american+motors',
#   'flags': ['USA', 'Canada']},
#  {'name': 'AMPHICAR',
#   'url': 'https://www.rockauto.com/en/catalog/amphicar',
#   'flags': ['USA']},
#  {'name': 'APOLLO',
#   'url': 'https://www.rockauto.com/en/catalog/apollo',
#   'flags': ['USA']},
#  {'name': 'ARMSTRONG-SIDDELEY',
#   'url': 'https://www.rockauto.com/en/catalog/armstrong-siddeley',
#   'flags': ['USA']},
#  {'name': 'ARNOLT-BRISTOL',
#   'url': 'https://www.rockauto.com/en/catalog/arnolt-bristol',
#   'flags': ['USA']},
#  {'name': 'ARNOLT-MG',
#   'url': 'https://www.rockauto.com/en/catalog/arnolt-mg',
#   'flags': ['USA']},
#  {'name': 'ASTON MARTIN',
#   'url': 'https://www.rockauto.com/en/catalog/aston+martin',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'ASUNA',
#   'url': 'https://www.rockauto.com/en/catalog/asuna',
#   'flags': ['Canada']},
#  {'name': 'AUBURN',
#   'url': 'https://www.rockauto.com/en/catalog/auburn',
#   'flags': ['USA']},
#  {'name': 'AUDI',
#   'url': 'https://www.rockauto.com/en/catalog/audi',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'AUSTIN',
#   'url': 'https://www.rockauto.com/en/catalog/austin',
#   'flags': ['USA', 'Canada']},
#  {'name': 'AUSTIN-HEALEY',
#   'url': 'https://www.rockauto.com/en/catalog/austin-healey',
#   'flags': ['USA', 'Canada']},
#  {'name': 'AVANTI',
#   'url': 'https://www.rockauto.com/en/catalog/avanti',
#   'flags': ['USA', 'Canada']},
#  {'name': 'BAIC',
#   'url': 'https://www.rockauto.com/en/catalog/baic',
#   'flags': ['Mexico']},
#  {'name': 'BENTLEY',
#   'url': 'https://www.rockauto.com/en/catalog/bentley',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'BERKELEY',
#   'url': 'https://www.rockauto.com/en/catalog/berkeley',
#   'flags': ['USA']},
#  {'name': 'BIZZARRINI',
#   'url': 'https://www.rockauto.com/en/catalog/bizzarrini',
#   'flags': ['USA']},
#  {'name': 'BMW',
#   'url': 'https://www.rockauto.com/en/catalog/bmw',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'BOND',
#   'url': 'https://www.rockauto.com/en/catalog/bond',
#   'flags': ['USA']},
#  {'name': 'BORGWARD',
#   'url': 'https://www.rockauto.com/en/catalog/borgward',
#   'flags': ['USA']},
#  {'name': 'BRICKLIN',
#   'url': 'https://www.rockauto.com/en/catalog/bricklin',
#   'flags': ['USA']},
#  {'name': 'BRISTOL',
#   'url': 'https://www.rockauto.com/en/catalog/bristol',
#   'flags': ['USA']},
#  {'name': 'BUGATTI',
#   'url': 'https://www.rockauto.com/en/catalog/bugatti',
#   'flags': ['USA', 'Canada']},
#  {'name': 'BUICK',
#   'url': 'https://www.rockauto.com/en/catalog/buick',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'CADILLAC',
#   'url': 'https://www.rockauto.com/en/catalog/cadillac',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'CASE',
#   'url': 'https://www.rockauto.com/en/catalog/case',
#   'flags': ['USA']},
#  {'name': 'CHECKER',
#   'url': 'https://www.rockauto.com/en/catalog/checker',
#   'flags': ['USA', 'Canada']},
#  {'name': 'CHEVROLET',
#   'url': 'https://www.rockauto.com/en/catalog/chevrolet',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'CHRYSLER',
#   'url': 'https://www.rockauto.com/en/catalog/chrysler',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'CISITALIA',
#   'url': 'https://www.rockauto.com/en/catalog/cisitalia',
#   'flags': ['USA']},
#  {'name': 'CITROEN',
#   'url': 'https://www.rockauto.com/en/catalog/citroen',
#   'flags': ['USA', 'Canada']},
#  {'name': 'COLE',
#   'url': 'https://www.rockauto.com/en/catalog/cole',
#   'flags': ['USA']},
#  {'name': 'CONTINENTAL',
#   'url': 'https://www.rockauto.com/en/catalog/continental',
#   'flags': ['USA']},
#  {'name': 'CORD',
#   'url': 'https://www.rockauto.com/en/catalog/cord',
#   'flags': ['USA']},
#  {'name': 'CROSLEY',
#   'url': 'https://www.rockauto.com/en/catalog/crosley',
#   'flags': ['USA']},
#  {'name': 'CUNNINGHAM',
#   'url': 'https://www.rockauto.com/en/catalog/cunningham',
#   'flags': ['USA']},
#  {'name': 'DAEWOO',
#   'url': 'https://www.rockauto.com/en/catalog/daewoo',
#   'flags': ['USA', 'Canada']},
#  {'name': 'DAF',
#   'url': 'https://www.rockauto.com/en/catalog/daf',
#   'flags': ['USA']},
#  {'name': 'DAIHATSU',
#   'url': 'https://www.rockauto.com/en/catalog/daihatsu',
#   'flags': ['USA', 'Canada']},
#  {'name': 'DAIMLER',
#   'url': 'https://www.rockauto.com/en/catalog/daimler',
#   'flags': ['USA']},
#  {'name': 'DATSUN',
#   'url': 'https://www.rockauto.com/en/catalog/datsun',
#   'flags': ['Mexico']},
#  {'name': 'DELAGE',
#   'url': 'https://www.rockauto.com/en/catalog/delage',
#   'flags': ['USA']},
#  {'name': 'DELAHAYE',
#   'url': 'https://www.rockauto.com/en/catalog/delahaye',
#   'flags': ['USA']},
#  {'name': 'DELLOW',
#   'url': 'https://www.rockauto.com/en/catalog/dellow',
#   'flags': ['USA']},
#  {'name': 'DELOREAN',
#   'url': 'https://www.rockauto.com/en/catalog/delorean',
#   'flags': ['USA', 'Canada']},
#  {'name': 'DENZEL',
#   'url': 'https://www.rockauto.com/en/catalog/denzel',
#   'flags': ['USA']},
#  {'name': 'DESOTO',
#   'url': 'https://www.rockauto.com/en/catalog/desoto',
#   'flags': ['USA']},
#  {'name': 'DETOMASO',
#   'url': 'https://www.rockauto.com/en/catalog/detomaso',
#   'flags': ['USA']},
#  {'name': 'DEUTSCH-BONNET',
#   'url': 'https://www.rockauto.com/en/catalog/deutsch-bonnet',
#   'flags': ['USA']},
#  {'name': 'DIANA',
#   'url': 'https://www.rockauto.com/en/catalog/diana',
#   'flags': ['USA']},
#  {'name': 'DKW',
#   'url': 'https://www.rockauto.com/en/catalog/dkw',
#   'flags': ['USA']},
#  {'name': 'DODGE',
#   'url': 'https://www.rockauto.com/en/catalog/dodge',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'DORETTI',
#   'url': 'https://www.rockauto.com/en/catalog/doretti',
#   'flags': ['USA']},
#  {'name': 'DU PONT',
#   'url': 'https://www.rockauto.com/en/catalog/du+pont',
#   'flags': ['USA']},
#  {'name': 'DUAL-GHIA',
#   'url': 'https://www.rockauto.com/en/catalog/dual-ghia',
#   'flags': ['USA']},
#  {'name': 'DUESENBERG',
#   'url': 'https://www.rockauto.com/en/catalog/duesenberg',
#   'flags': ['USA']},
#  {'name': 'DURANT',
#   'url': 'https://www.rockauto.com/en/catalog/durant',
#   'flags': ['USA']},
#  {'name': 'EAGLE',
#   'url': 'https://www.rockauto.com/en/catalog/eagle',
#   'flags': ['USA', 'Canada']},
#  {'name': 'EDSEL',
#   'url': 'https://www.rockauto.com/en/catalog/edsel',
#   'flags': ['USA', 'Canada']},
#  {'name': 'ELCAR',
#   'url': 'https://www.rockauto.com/en/catalog/elcar',
#   'flags': ['USA']},
#  {'name': 'ELVA',
#   'url': 'https://www.rockauto.com/en/catalog/elva',
#   'flags': ['USA']},
#  {'name': 'ERSKINE',
#   'url': 'https://www.rockauto.com/en/catalog/erskine',
#   'flags': ['USA']},
#  {'name': 'ESSEX',
#   'url': 'https://www.rockauto.com/en/catalog/essex',
#   'flags': ['USA']},
#  {'name': 'EXCALIBUR',
#   'url': 'https://www.rockauto.com/en/catalog/excalibur',
#   'flags': ['USA']},
#  {'name': 'FACEL VEGA',
#   'url': 'https://www.rockauto.com/en/catalog/facel+vega',
#   'flags': ['USA']},
#  {'name': 'FAIRTHORPE',
#   'url': 'https://www.rockauto.com/en/catalog/fairthorpe',
#   'flags': ['USA']},
#  {'name': 'FALCON KNIGHT',
#   'url': 'https://www.rockauto.com/en/catalog/falcon+knight',
#   'flags': ['USA']},
#  {'name': 'FARGO',
#   'url': 'https://www.rockauto.com/en/catalog/fargo',
#   'flags': ['USA', 'Canada']},
#  {'name': 'FAW',
#   'url': 'https://www.rockauto.com/en/catalog/faw',
#   'flags': ['Mexico']},
#  {'name': 'FERRARI',
#   'url': 'https://www.rockauto.com/en/catalog/ferrari',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'FIAT',
#   'url': 'https://www.rockauto.com/en/catalog/fiat',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'FISKER',
#   'url': 'https://www.rockauto.com/en/catalog/fisker',
#   'flags': ['USA']},
#  {'name': 'FLINT',
#   'url': 'https://www.rockauto.com/en/catalog/flint',
#   'flags': ['USA']},
#  {'name': 'FORD',
#   'url': 'https://www.rockauto.com/en/catalog/ford',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'FOTON',
#   'url': 'https://www.rockauto.com/en/catalog/foton',
#   'flags': ['Mexico']},
#  {'name': 'FRANKLIN',
#   'url': 'https://www.rockauto.com/en/catalog/franklin',
#   'flags': ['USA']},
#  {'name': 'FRAZER NASH',
#   'url': 'https://www.rockauto.com/en/catalog/frazer+nash',
#   'flags': ['USA']},
#  {'name': 'FREIGHTLINER',
#   'url': 'https://www.rockauto.com/en/catalog/freightliner',
#   'flags': ['USA', 'Canada']},
#  {'name': 'GARDNER',
#   'url': 'https://www.rockauto.com/en/catalog/gardner',
#   'flags': ['USA']},
#  {'name': 'GENESIS',
#   'url': 'https://www.rockauto.com/en/catalog/genesis',
#   'flags': ['USA', 'Canada']},
#  {'name': 'GEO',
#   'url': 'https://www.rockauto.com/en/catalog/geo',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'GIANT MOTORS',
#   'url': 'https://www.rockauto.com/en/catalog/giant+motors',
#   'flags': ['Mexico']},
#  {'name': 'GLAS',
#   'url': 'https://www.rockauto.com/en/catalog/glas',
#   'flags': ['USA']},
#  {'name': 'GMC',
#   'url': 'https://www.rockauto.com/en/catalog/gmc',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'GOLIATH',
#   'url': 'https://www.rockauto.com/en/catalog/goliath',
#   'flags': ['USA']},
#  {'name': 'GORDON-KEEBLE',
#   'url': 'https://www.rockauto.com/en/catalog/gordon-keeble',
#   'flags': ['USA']},
#  {'name': 'GRAHAM',
#   'url': 'https://www.rockauto.com/en/catalog/graham',
#   'flags': ['USA']},
#  {'name': 'GRAHAM-PAIGE',
#   'url': 'https://www.rockauto.com/en/catalog/graham-paige',
#   'flags': ['USA']},
#  {'name': 'GRIFFITH',
#   'url': 'https://www.rockauto.com/en/catalog/griffith',
#   'flags': ['USA']},
#  {'name': 'HEALEY',
#   'url': 'https://www.rockauto.com/en/catalog/healey',
#   'flags': ['USA']},
#  {'name': 'HENRY J',
#   'url': 'https://www.rockauto.com/en/catalog/henry+j',
#   'flags': ['USA']},
#  {'name': 'HILLMAN',
#   'url': 'https://www.rockauto.com/en/catalog/hillman',
#   'flags': ['USA', 'Canada']},
#  {'name': 'HINO',
#   'url': 'https://www.rockauto.com/en/catalog/hino',
#   'flags': ['USA', 'Canada']},
#  {'name': 'HISPANO-SUIZA',
#   'url': 'https://www.rockauto.com/en/catalog/hispano-suiza',
#   'flags': ['USA']},
#  {'name': 'HONDA',
#   'url': 'https://www.rockauto.com/en/catalog/honda',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'HOTCHKISS',
#   'url': 'https://www.rockauto.com/en/catalog/hotchkiss',
#   'flags': ['USA']},
#  {'name': 'HRG',
#   'url': 'https://www.rockauto.com/en/catalog/hrg',
#   'flags': ['USA']},
#  {'name': 'HUDSON',
#   'url': 'https://www.rockauto.com/en/catalog/hudson',
#   'flags': ['USA']},
#  {'name': 'HUMBER',
#   'url': 'https://www.rockauto.com/en/catalog/humber',
#   'flags': ['USA']},
#  {'name': 'HUMMER',
#   'url': 'https://www.rockauto.com/en/catalog/hummer',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'HUPMOBILE',
#   'url': 'https://www.rockauto.com/en/catalog/hupmobile',
#   'flags': ['USA']},
#  {'name': 'HYUNDAI',
#   'url': 'https://www.rockauto.com/en/catalog/hyundai',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'INFINITI',
#   'url': 'https://www.rockauto.com/en/catalog/infiniti',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'INTERNATIONAL',
#   'url': 'https://www.rockauto.com/en/catalog/international',
#   'flags': ['USA', 'Canada']},
#  {'name': 'ISO',
#   'url': 'https://www.rockauto.com/en/catalog/iso',
#   'flags': ['USA']},
#  {'name': 'ISUZU',
#   'url': 'https://www.rockauto.com/en/catalog/isuzu',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'IVECO',
#   'url': 'https://www.rockauto.com/en/catalog/iveco',
#   'flags': ['USA']},
#  {'name': 'JAC',
#   'url': 'https://www.rockauto.com/en/catalog/jac',
#   'flags': ['Mexico']},
#  {'name': 'JAGUAR',
#   'url': 'https://www.rockauto.com/en/catalog/jaguar',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'JEEP',
#   'url': 'https://www.rockauto.com/en/catalog/jeep',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'JENSEN',
#   'url': 'https://www.rockauto.com/en/catalog/jensen',
#   'flags': ['USA', 'Canada']},
#  {'name': 'JEWETT',
#   'url': 'https://www.rockauto.com/en/catalog/jewett',
#   'flags': ['USA']},
#  {'name': 'JORDAN',
#   'url': 'https://www.rockauto.com/en/catalog/jordan',
#   'flags': ['USA']},
#  {'name': 'JOWETT',
#   'url': 'https://www.rockauto.com/en/catalog/jowett',
#   'flags': ['USA']},
#  {'name': 'KAISER-FRAZER',
#   'url': 'https://www.rockauto.com/en/catalog/kaiser-frazer',
#   'flags': ['USA']},
#  {'name': 'KARMA',
#   'url': 'https://www.rockauto.com/en/catalog/karma',
#   'flags': ['USA', 'Canada']},
#  {'name': 'KENWORTH',
#   'url': 'https://www.rockauto.com/en/catalog/kenworth',
#   'flags': ['USA', 'Canada']},
#  {'name': 'KIA',
#   'url': 'https://www.rockauto.com/en/catalog/kia',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'KISSEL',
#   'url': 'https://www.rockauto.com/en/catalog/kissel',
#   'flags': ['USA']},
#  {'name': 'KURTIS',
#   'url': 'https://www.rockauto.com/en/catalog/kurtis',
#   'flags': ['USA']},
#  {'name': 'LADA',
#   'url': 'https://www.rockauto.com/en/catalog/lada',
#   'flags': ['USA', 'Canada']},
#  {'name': 'LAFORZA',
#   'url': 'https://www.rockauto.com/en/catalog/laforza',
#   'flags': ['USA', 'Canada']},
#  {'name': 'LAGONDA',
#   'url': 'https://www.rockauto.com/en/catalog/lagonda',
#   'flags': ['USA']},
#  {'name': 'LAMBORGHINI',
#   'url': 'https://www.rockauto.com/en/catalog/lamborghini',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'LANCHESTER',
#   'url': 'https://www.rockauto.com/en/catalog/lanchester',
#   'flags': ['USA']},
#  {'name': 'LANCIA',
#   'url': 'https://www.rockauto.com/en/catalog/lancia',
#   'flags': ['USA', 'Canada']},
#  {'name': 'LAND ROVER',
#   'url': 'https://www.rockauto.com/en/catalog/land+rover',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'LASALLE',
#   'url': 'https://www.rockauto.com/en/catalog/lasalle',
#   'flags': ['USA']},
#  {'name': 'LEA-FRANCIS',
#   'url': 'https://www.rockauto.com/en/catalog/lea-francis',
#   'flags': ['USA']},
#  {'name': 'LEXINGTON',
#   'url': 'https://www.rockauto.com/en/catalog/lexington',
#   'flags': ['USA']},
#  {'name': 'LEXUS',
#   'url': 'https://www.rockauto.com/en/catalog/lexus',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'LINCOLN',
#   'url': 'https://www.rockauto.com/en/catalog/lincoln',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'LOTUS',
#   'url': 'https://www.rockauto.com/en/catalog/lotus',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MACK',
#   'url': 'https://www.rockauto.com/en/catalog/mack',
#   'flags': ['USA']},
#  {'name': 'MAICO',
#   'url': 'https://www.rockauto.com/en/catalog/maico',
#   'flags': ['USA']},
#  {'name': 'MARATHON',
#   'url': 'https://www.rockauto.com/en/catalog/marathon',
#   'flags': ['USA']},
#  {'name': 'MARAUDER',
#   'url': 'https://www.rockauto.com/en/catalog/marauder',
#   'flags': ['USA']},
#  {'name': 'MARCOS',
#   'url': 'https://www.rockauto.com/en/catalog/marcos',
#   'flags': ['USA']},
#  {'name': 'MARMON',
#   'url': 'https://www.rockauto.com/en/catalog/marmon',
#   'flags': ['USA']},
#  {'name': 'MASERATI',
#   'url': 'https://www.rockauto.com/en/catalog/maserati',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MASTRETTA',
#   'url': 'https://www.rockauto.com/en/catalog/mastretta',
#   'flags': ['Mexico']},
#  {'name': 'MATRA',
#   'url': 'https://www.rockauto.com/en/catalog/matra',
#   'flags': ['USA']},
#  {'name': 'MAXWELL',
#   'url': 'https://www.rockauto.com/en/catalog/maxwell',
#   'flags': ['USA']},
#  {'name': 'MAYBACH',
#   'url': 'https://www.rockauto.com/en/catalog/maybach',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MAZDA',
#   'url': 'https://www.rockauto.com/en/catalog/mazda',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MCLAREN',
#   'url': 'https://www.rockauto.com/en/catalog/mclaren',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MERCEDES-BENZ',
#   'url': 'https://www.rockauto.com/en/catalog/mercedes-benz',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MERCURY',
#   'url': 'https://www.rockauto.com/en/catalog/mercury',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MERKUR',
#   'url': 'https://www.rockauto.com/en/catalog/merkur',
#   'flags': ['USA', 'Canada']},
#  {'name': 'MESSERSCHMITT',
#   'url': 'https://www.rockauto.com/en/catalog/messerschmitt',
#   'flags': ['USA']},
#  {'name': 'MG',
#   'url': 'https://www.rockauto.com/en/catalog/mg',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MINI',
#   'url': 'https://www.rockauto.com/en/catalog/mini',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MITSUBISHI',
#   'url': 'https://www.rockauto.com/en/catalog/mitsubishi',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'MITSUBISHI FUSO',
#   'url': 'https://www.rockauto.com/en/catalog/mitsubishi+fuso',
#   'flags': ['USA']},
#  {'name': 'MOBILITY VENTURES',
#   'url': 'https://www.rockauto.com/en/catalog/mobility+ventures',
#   'flags': ['USA', 'Canada']},
#  {'name': 'MONTEVERDI',
#   'url': 'https://www.rockauto.com/en/catalog/monteverdi',
#   'flags': ['USA']},
#  {'name': 'MOON',
#   'url': 'https://www.rockauto.com/en/catalog/moon',
#   'flags': ['USA']},
#  {'name': 'MORETTI',
#   'url': 'https://www.rockauto.com/en/catalog/moretti',
#   'flags': ['USA']},
#  {'name': 'MORGAN',
#   'url': 'https://www.rockauto.com/en/catalog/morgan',
#   'flags': ['USA', 'Canada']},
#  {'name': 'MORRIS',
#   'url': 'https://www.rockauto.com/en/catalog/morris',
#   'flags': ['USA']},
#  {'name': 'MOSKVICH',
#   'url': 'https://www.rockauto.com/en/catalog/moskvich',
#   'flags': ['USA']},
#  {'name': 'NARDI',
#   'url': 'https://www.rockauto.com/en/catalog/nardi',
#   'flags': ['USA']},
#  {'name': 'NASH',
#   'url': 'https://www.rockauto.com/en/catalog/nash',
#   'flags': ['USA']},
#  {'name': 'NISSAN',
#   'url': 'https://www.rockauto.com/en/catalog/nissan',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'NSU',
#   'url': 'https://www.rockauto.com/en/catalog/nsu',
#   'flags': ['USA']},
#  {'name': 'OAKLAND',
#   'url': 'https://www.rockauto.com/en/catalog/oakland',
#   'flags': ['USA']},
#  {'name': 'OLDSMOBILE',
#   'url': 'https://www.rockauto.com/en/catalog/oldsmobile',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'OMEGA',
#   'url': 'https://www.rockauto.com/en/catalog/omega',
#   'flags': ['USA']},
#  {'name': 'OPEL',
#   'url': 'https://www.rockauto.com/en/catalog/opel',
#   'flags': ['USA', 'Canada']},
#  {'name': 'OSCA',
#   'url': 'https://www.rockauto.com/en/catalog/osca',
#   'flags': ['USA']},
#  {'name': 'PACKARD',
#   'url': 'https://www.rockauto.com/en/catalog/packard',
#   'flags': ['USA']},
#  {'name': 'PAIGE',
#   'url': 'https://www.rockauto.com/en/catalog/paige',
#   'flags': ['USA']},
#  {'name': 'PANHARD',
#   'url': 'https://www.rockauto.com/en/catalog/panhard',
#   'flags': ['USA']},
#  {'name': 'PANOZ',
#   'url': 'https://www.rockauto.com/en/catalog/panoz',
#   'flags': ['USA']},
#  {'name': 'PANTHER',
#   'url': 'https://www.rockauto.com/en/catalog/panther',
#   'flags': ['USA']},
#  {'name': 'PASSPORT',
#   'url': 'https://www.rockauto.com/en/catalog/passport',
#   'flags': ['Canada']},
#  {'name': 'PEERLESS',
#   'url': 'https://www.rockauto.com/en/catalog/peerless',
#   'flags': ['USA']},
#  {'name': 'PEGASO',
#   'url': 'https://www.rockauto.com/en/catalog/pegaso',
#   'flags': ['USA']},
#  {'name': 'PETERBILT',
#   'url': 'https://www.rockauto.com/en/catalog/peterbilt',
#   'flags': ['USA', 'Canada']},
#  {'name': 'PEUGEOT',
#   'url': 'https://www.rockauto.com/en/catalog/peugeot',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'PIERCE-ARROW',
#   'url': 'https://www.rockauto.com/en/catalog/pierce-arrow',
#   'flags': ['USA']},
#  {'name': 'PLYMOUTH',
#   'url': 'https://www.rockauto.com/en/catalog/plymouth',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'POLESTAR',
#   'url': 'https://www.rockauto.com/en/catalog/polestar',
#   'flags': ['USA', 'Canada']},
#  {'name': 'PONTIAC',
#   'url': 'https://www.rockauto.com/en/catalog/pontiac',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'PORSCHE',
#   'url': 'https://www.rockauto.com/en/catalog/porsche',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'QVALE',
#   'url': 'https://www.rockauto.com/en/catalog/qvale',
#   'flags': ['USA']},
#  {'name': 'RAM',
#   'url': 'https://www.rockauto.com/en/catalog/ram',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'RELIANT',
#   'url': 'https://www.rockauto.com/en/catalog/reliant',
#   'flags': ['USA']},
#  {'name': 'RENAULT',
#   'url': 'https://www.rockauto.com/en/catalog/renault',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'REO',
#   'url': 'https://www.rockauto.com/en/catalog/reo',
#   'flags': ['USA']},
#  {'name': 'RICKENBACKER',
#   'url': 'https://www.rockauto.com/en/catalog/rickenbacker',
#   'flags': ['USA']},
#  {'name': 'RILEY',
#   'url': 'https://www.rockauto.com/en/catalog/riley',
#   'flags': ['USA']},
#  {'name': 'RIVIAN',
#   'url': 'https://www.rockauto.com/en/catalog/rivian',
#   'flags': ['USA', 'Canada']},
#  {'name': 'ROAMER',
#   'url': 'https://www.rockauto.com/en/catalog/roamer',
#   'flags': ['USA']},
#  {'name': 'ROCKNE',
#   'url': 'https://www.rockauto.com/en/catalog/rockne',
#   'flags': ['USA']},
#  {'name': 'ROLLS-ROYCE',
#   'url': 'https://www.rockauto.com/en/catalog/rolls-royce',
#   'flags': ['USA', 'Canada']},
#  {'name': 'ROVER',
#   'url': 'https://www.rockauto.com/en/catalog/rover',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'SAAB',
#   'url': 'https://www.rockauto.com/en/catalog/saab',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'SABRA',
#   'url': 'https://www.rockauto.com/en/catalog/sabra',
#   'flags': ['USA']},
#  {'name': 'SALEEN',
#   'url': 'https://www.rockauto.com/en/catalog/saleen',
#   'flags': ['USA']},
#  {'name': 'SALMSON',
#   'url': 'https://www.rockauto.com/en/catalog/salmson',
#   'flags': ['USA']},
#  {'name': 'SATURN',
#   'url': 'https://www.rockauto.com/en/catalog/saturn',
#   'flags': ['USA', 'Canada']},
#  {'name': 'SCION',
#   'url': 'https://www.rockauto.com/en/catalog/scion',
#   'flags': ['USA', 'Canada']},
#  {'name': 'SEAT',
#   'url': 'https://www.rockauto.com/en/catalog/seat',
#   'flags': ['Mexico']},
#  {'name': 'SHELBY',
#   'url': 'https://www.rockauto.com/en/catalog/shelby',
#   'flags': ['USA', 'Canada']},
#  {'name': 'SIATA',
#   'url': 'https://www.rockauto.com/en/catalog/siata',
#   'flags': ['USA']},
#  {'name': 'SIMCA',
#   'url': 'https://www.rockauto.com/en/catalog/simca',
#   'flags': ['USA']},
#  {'name': 'SINGER',
#   'url': 'https://www.rockauto.com/en/catalog/singer',
#   'flags': ['USA']},
#  {'name': 'SKODA',
#   'url': 'https://www.rockauto.com/en/catalog/skoda',
#   'flags': ['USA']},
#  {'name': 'SMART',
#   'url': 'https://www.rockauto.com/en/catalog/smart',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'SPYKER',
#   'url': 'https://www.rockauto.com/en/catalog/spyker',
#   'flags': ['USA']},
#  {'name': 'SRT',
#   'url': 'https://www.rockauto.com/en/catalog/srt',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'STANDARD',
#   'url': 'https://www.rockauto.com/en/catalog/standard',
#   'flags': ['USA']},
#  {'name': 'STAR',
#   'url': 'https://www.rockauto.com/en/catalog/star',
#   'flags': ['USA']},
#  {'name': 'STEARNS KNIGHT',
#   'url': 'https://www.rockauto.com/en/catalog/stearns+knight',
#   'flags': ['USA']},
#  {'name': 'STERLING',
#   'url': 'https://www.rockauto.com/en/catalog/sterling',
#   'flags': ['USA', 'Canada']},
#  {'name': 'STEVENS-DURYEA',
#   'url': 'https://www.rockauto.com/en/catalog/stevens-duryea',
#   'flags': ['USA']},
#  {'name': 'STUDEBAKER',
#   'url': 'https://www.rockauto.com/en/catalog/studebaker',
#   'flags': ['USA']},
#  {'name': 'STUTZ',
#   'url': 'https://www.rockauto.com/en/catalog/stutz',
#   'flags': ['USA']},
#  {'name': 'SUBARU',
#   'url': 'https://www.rockauto.com/en/catalog/subaru',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'SUNBEAM',
#   'url': 'https://www.rockauto.com/en/catalog/sunbeam',
#   'flags': ['USA', 'Canada']},
#  {'name': 'SUZUKI',
#   'url': 'https://www.rockauto.com/en/catalog/suzuki',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'SWALLOW',
#   'url': 'https://www.rockauto.com/en/catalog/swallow',
#   'flags': ['USA']},
#  {'name': 'TALBOT-LAGO',
#   'url': 'https://www.rockauto.com/en/catalog/talbot-lago',
#   'flags': ['USA']},
#  {'name': 'TATRA',
#   'url': 'https://www.rockauto.com/en/catalog/tatra',
#   'flags': ['USA']},
#  {'name': 'TESLA',
#   'url': 'https://www.rockauto.com/en/catalog/tesla',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'THINK',
#   'url': 'https://www.rockauto.com/en/catalog/think',
#   'flags': ['USA']},
#  {'name': 'TOYOTA',
#   'url': 'https://www.rockauto.com/en/catalog/toyota',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'TRIUMPH',
#   'url': 'https://www.rockauto.com/en/catalog/triumph',
#   'flags': ['USA', 'Canada']},
#  {'name': 'TURNER',
#   'url': 'https://www.rockauto.com/en/catalog/turner',
#   'flags': ['USA']},
#  {'name': 'TVR',
#   'url': 'https://www.rockauto.com/en/catalog/tvr',
#   'flags': ['USA']},
#  {'name': 'UAZ',
#   'url': 'https://www.rockauto.com/en/catalog/uaz',
#   'flags': ['Mexico']},
#  {'name': 'UD',
#   'url': 'https://www.rockauto.com/en/catalog/ud',
#   'flags': ['USA', 'Canada']},
#  {'name': 'UTILIMASTER',
#   'url': 'https://www.rockauto.com/en/catalog/utilimaster',
#   'flags': ['USA', 'Canada']},
#  {'name': 'VAM',
#   'url': 'https://www.rockauto.com/en/catalog/vam',
#   'flags': ['Mexico']},
#  {'name': 'VAUXHALL',
#   'url': 'https://www.rockauto.com/en/catalog/vauxhall',
#   'flags': ['USA']},
#  {'name': 'VESPA',
#   'url': 'https://www.rockauto.com/en/catalog/vespa',
#   'flags': ['USA']},
#  {'name': 'VOLKSWAGEN',
#   'url': 'https://www.rockauto.com/en/catalog/volkswagen',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'VOLVO',
#   'url': 'https://www.rockauto.com/en/catalog/volvo',
#   'flags': ['USA', 'Canada', 'Mexico']},
#  {'name': 'VPG',
#   'url': 'https://www.rockauto.com/en/catalog/vpg',
#   'flags': ['USA']},
#  {'name': 'WARTBURG',
#   'url': 'https://www.rockauto.com/en/catalog/wartburg',
#   'flags': ['USA']},
#  {'name': 'WESTCOTT',
#   'url': 'https://www.rockauto.com/en/catalog/westcott',
#   'flags': ['USA']},
#  {'name': 'WHIPPET',
#   'url': 'https://www.rockauto.com/en/catalog/whippet',
#   'flags': ['USA']},
#  {'name': 'WILLYS',
#   'url': 'https://www.rockauto.com/en/catalog/willys',
#   'flags': ['USA']},
#  {'name': 'WINDSOR',
#   'url': 'https://www.rockauto.com/en/catalog/windsor',
#   'flags': ['USA']},
#  {'name': 'WOLSELEY',
#   'url': 'https://www.rockauto.com/en/catalog/wolseley',
#   'flags': ['USA']},
#  {'name': 'WORKHORSE',
#   'url': 'https://www.rockauto.com/en/catalog/workhorse',
#   'flags': ['USA', 'Canada']},
#  {'name': 'YELLOW CAB',
#   'url': 'https://www.rockauto.com/en/catalog/yellow+cab',
#   'flags': ['USA']},
#  {'name': 'YUGO',
#   'url': 'https://www.rockauto.com/en/catalog/yugo',
#   'flags': ['USA', 'Canada']},
#  {'name': 'ZACUA',
#   'url': 'https://www.rockauto.com/en/catalog/zacua',
#   'flags': ['Mexico']},
#  {'name': 'ZUNDAPP',
#   'url': 'https://www.rockauto.com/en/catalog/zundapp',
#   'flags': ['USA']}]

# %% [markdown]
# ### ABARTH --> 1996--> 2

# %%
url2 = url_1
r2 = act_req.get("https://www.rockauto.com/en/catalog/abarth")
print(r2.url)
soup2 = BeautifulSoup(r2.text, 'html.parser')
# Out:
# https://www.rockauto.com/en/catalog/abarth

# %%
tag1 = soup2.findAll('div', {'class': 'ranavnode'})

# %%
dom=[]
for x in tag1:
    temp=x.find('tr')
    dom.append(temp)

# %%
data_orig2 = []
for v in dom[1:]:
    data2={}
    
    chck = v.find('a', {'class': 'navlabellink nvoffset nnormal'})
    
    if chck == None:
        chck = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data['name'] = 'important'
    url_2 = urljoin(url2, chck.get('href'))
    name_2 = chck.text
    
    data2["name"] = name_2
    data2["url"] = url_2
    
    data_orig2.append(data2)

data_orig2
# Out:
# [{'name': '1969', 'url': 'https://www.rockauto.com/en/catalog/abarth,1969'},
#  {'name': '1968', 'url': 'https://www.rockauto.com/en/catalog/abarth,1968'},
#  {'name': '1967', 'url': 'https://www.rockauto.com/en/catalog/abarth,1967'},
#  {'name': '1966', 'url': 'https://www.rockauto.com/en/catalog/abarth,1966'},
#  {'name': '1965', 'url': 'https://www.rockauto.com/en/catalog/abarth,1965'},
#  {'name': '1964', 'url': 'https://www.rockauto.com/en/catalog/abarth,1964'},
#  {'name': '1963', 'url': 'https://www.rockauto.com/en/catalog/abarth,1963'},
#  {'name': '1962', 'url': 'https://www.rockauto.com/en/catalog/abarth,1962'},
#  {'name': '1961', 'url': 'https://www.rockauto.com/en/catalog/abarth,1961'},
#  {'name': '1960', 'url': 'https://www.rockauto.com/en/catalog/abarth,1960'},
#  {'name': '1959', 'url': 'https://www.rockauto.com/en/catalog/abarth,1959'},
#  {'name': '1958', 'url': 'https://www.rockauto.com/en/catalog/abarth,1958'},
#  {'name': '1957', 'url': 'https://www.rockauto.com/en/catalog/abarth,1957'},
#  {'name': '1956', 'url': 'https://www.rockauto.com/en/catalog/abarth,1956'},
#  {'name': '1955', 'url': 'https://www.rockauto.com/en/catalog/abarth,1955'},
#  {'name': '1954', 'url': 'https://www.rockauto.com/en/catalog/abarth,1954'},
#  {'name': '1953', 'url': 'https://www.rockauto.com/en/catalog/abarth,1953'},
#  {'name': '1952', 'url': 'https://www.rockauto.com/en/catalog/abarth,1952'},
#  {'name': '1951', 'url': 'https://www.rockauto.com/en/catalog/abarth,1951'},
#  {'name': '1950', 'url': 'https://www.rockauto.com/en/catalog/abarth,1950'}]

# %% [markdown]
# # year - 3

# %% [markdown]
# ### ABARTH --> 1996-

# %%
url3 = url_2
r3 = act_req.get("https://www.rockauto.com/en/catalog/abarth,1966")
print(r3.url)
soup3 = BeautifulSoup(r3.text, 'html.parser')
# Out:
# https://www.rockauto.com/en/catalog/abarth,1966

# %%
tag3 = soup3.findAll('div', {'class': 'inner'})
om=[]
for x in tag3:
    temp=x.find('tr')
    om.append(temp)

# %%
data_orig3 = []

for v in om[2:]:
    data3={}
    
    chck = v.find('a', {'class': 'navlabellink nvoffset nnormal'})
    
    if chck == None:
        chck = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data['name'] = 'important'
    url_3 = urljoin(url3, chck.get('href'))
    name_3 = chck.text
    
    data3["name"] = name_3
    data3["url"] = url_3
    
    data_orig3.append(data3)

data_orig3
# Out:
# [{'name': '1000',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,1000'},
#  {'name': '1150',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,1150'},
#  {'name': '1600',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,1600'},
#  {'name': '2000',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,2000'},
#  {'name': '850', 'url': 'https://www.rockauto.com/en/catalog/abarth,1966,850'},
#  {'name': 'SIMCA',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca'}]

# %% [markdown]
# # ABARTH --> 1996--> 1000 --> 	982cc L4		RSS Feed  - 4

# %%
url4 = url_3
r4 = act_req.get(url_3)
soup4 = BeautifulSoup(r4.text, 'html.parser')

# %%
tag4 = soup4.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
omm=[]
for x in tag4:
    temp=x.find('tr')
    omm.append(temp)

# %%
for dta in omm:
    if 'href="/RSS' in str(dta):
        RSS_url = urljoin(url4, dta.find('a',{'target': '_blank'})['href'])
        print(RSS_url)
# Out:
# https://www.rockauto.com/RSS/subscribe.php?carcode=1439098
# https://www.rockauto.com/RSS/subscribe.php?carcode=1492800

# %%
data_orig4 = []
for v in omm[3:]:
    data4={}
    
    chck = v.find('a', {'class': 'navlabellink nvoffset nnormal'})
    
    if chck == None:
        chck = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data['name'] = 'important'
    url_4 = urljoin(url4, chck.get('href'))
    name_4 = chck.text
    for dta in omm:
        if 'href="/RSS' in str(dta):
            RSS_url = urljoin(url4, dta.find('a',{'target': '_blank'})['href'])
    
    data4["name"] = name_4
    data4["url"] = url_4
    data4["Really Simple Syndication"] = RSS_url
    data_orig4.append(data4)
#https://www.rockauto.com/en/catalog/zundapp,1956,janus+250,245cc+l1,1438661

data_orig4
# Out:
# [{'name': '1.3L L4',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,1.3l+l4,1439098',
#   'Really Simple Syndication': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492800'},
#  {'name': '2.0L L4',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800',
#   'Really Simple Syndication': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492800'}]

# %% [markdown]
# # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed

# %%
url5 = url_4
r5 = act_req.get(url_4)
print(r5.url)
soup5 = BeautifulSoup(r5.text, 'html.parser')
# Out:
# https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800

# %%
tag5 = soup5.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
omm=[]
for x in tag5:
    temp=x.find('tr')
    omm.append(temp)

# %%
data_orig5 = []

for v in omm[4:]:
    data5={}
    
    chck = v.find('a', {'class': 'navlabellink nvoffset nnormal'})
    
    if chck == None:
        chck = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data5['name'] = 'important'
    url_5 = urljoin(url5, chck.get('href'))
    name_5 = chck.text
    
    data5["name"] = name_5
    data5["url"] = url_5
    
    data_orig5.append(data5)

data_orig5
# Out:
# [{'name': 'Brake & Wheel Hub',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,brake+&+wheel+hub'},
#  {'name': 'Cooling System',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,cooling+system'},
#  {'name': 'Electrical-Bulb & Socket',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,electrical-bulb+&+socket'},
#  {'name': 'Ignition',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,ignition'},
#  {'name': 'Wiper & Washer',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,wiper+&+washer'}]

# %% [markdown]
# # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed --> Brake & Wheel Hub --> Brake Pad - 6

# %%
url6 = url_5
r6 = act_req.get(url_5)
print(r6.url)
soup6 = BeautifulSoup(r6.text, 'html.parser')
# Out:
# https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,wiper+&+washer

# %%
tag6 = soup6.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
omt=[]
for x in tag6:
    temp=x.find('tr')
    omt.append(temp)

# %%
data_orig6 = []

for v in omt[5:]:
    data6={}
    
    chck6 = v.find('a', {'class': 'navlabellink nvoffset nnormal'})
    
    if chck6 == None:
        chck6 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data6['name'] = 'important'
    url_6 = urljoin(url6, chck6.get('href'))
    name_6 = chck.text
    
    data6["name"] = name_6
    data6["url"] = url_6
    
    data_orig6.append(data6)

data_orig6
# Out:
# [{'name': 'Wiper & Washer',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,wiper+&+washer,wiper+arm,8848'},
#  {'name': 'Wiper & Washer',
#   'url': 'https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,wiper+&+washer,wiper+blade,8852'}]

# %% [markdown]
# # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed --> Brake & Wheel Hub --> Brake Pad --> INFO  ->7

# %%
url7 = url_6
r7 = act_req.get(url_6)
print(r7.url)
soup7 = BeautifulSoup(r7.text, 'html.parser')
# Out:
# https://www.rockauto.com/en/catalog/abarth,1966,simca,2.0l+l4,1492800,wiper+&+washer,wiper+blade,8852

# %%
table_v = soup7.find('form', {'class': 'nobmp', 'method': 'post'}).findAll('div', {'class': 'listing-text-row-moreinfo-truck'})

# %%
data_orig7 = []
for dta in table_v:
    data={}
    d1 = d2 = "Null"
    try:
        d1 = dta.text.strip()
    except:
        pass
    try:
        d2 = dta.find('a')['href']
    except:
        pass
    data.update({d1: d2})
    data_orig7.append(data)
data_orig7
# Out:
# [{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1492800&pt=8852'},
#  {'TRICO 111 Exact Fit; 11" (280mm) 5mm Bayonet, 6/8mm Hook Type Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50714&cc=1492800&pt=8852'},
#  {'ANCO 3011 Winter; Conventional Blade w/ Anti-Icing Boots; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532586&cc=1492800&pt=8852'},
#  {'TRICO 37111 Chill; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50763&cc=1492800&pt=8852'}]

# %%
li = {'Make': name_1,
      'country': flags_1,
      'Year': name_2, 
      'Model': name_3, 
      'Part': name_4, 
      'Product':name_5 ,
      'Really Simple Syndication_URL' : RSS_url, 
      'Sub_Product': name_6, 
      'Product_Name_Info_Link': [data_orig7]}
li
# Out:
# {'Make': 'ZUNDAPP',
#  'country': ['USA'],
#  'Year': '1950',
#  'Model': 'SIMCA',
#  'Part': '2.0L L4',
#  'Product': 'Wiper & Washer',
#  'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492800',
#  'Sub_Product': 'Wiper Blade',
#  'Product_Name_Info_Link': [[{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1492800&pt=8852'},
#    {'TRICO 111 Exact Fit; 11" (280mm) 5mm Bayonet, 6/8mm Hook Type Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50714&cc=1492800&pt=8852'},
#    {'ANCO 3011 Winter; Conventional Blade w/ Anti-Icing Boots; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532586&cc=1492800&pt=8852'},
#    {'TRICO 37111 Chill; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50763&cc=1492800&pt=8852'}]]}

# %%
# df = pd.DataFrame(li)

# df.to_excel('RockAuto.xlsx', index=False)
# print(df)

# %%
# df = pd.DataFrame(li)

# df.to_excel('RockAuto.xlsx', index=False)
# print(df)

# %%
# df = pd.read_excel('RockAuto.xlsx')
# df

# %%
import requests, json
from bs4 import BeautifulSoup
from urllib.parse import urljoin

filename = 'Final_Rock.json'

base_url = 'https://www.rockauto.com/'
act_req = requests.Session()
r1 = act_req.get("https://www.rockauto.com/en/catalog/")
soup = BeautifulSoup(r1.text, 'html.parser')
tags = soup.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
random = []
for x in tags:
    temp = x.find('tr')
    random.append(temp)
data_orig1 = []


# For front page  - 1


for y in random:
    data = {}

    # print(y)

    chck1 = y.find('a', {'class': 'navlabellink nvoffset nnormal'})
    if chck1 is None:
        chck1 = y.find('a', {'class': 'navlabellink nvoffset nimportant'})
        data['name'] = 'important'
    # global url_1
    url_1 = urljoin(base_url, chck1.get('href'))
    print(url_1)

    flg = y.find('td', {'class': 'rc nflags'})
    flags_1 = [d.get('aria-label').replace('flag', '').split('the')[-1].strip() for d in flg.findAll('a')]

    name_1 = chck1.text
    data["name"] = name_1
    data["url"] = url_1
    data['flags'] = flags_1

    data_orig1.append(data)

    #  ABARTH --> 1996--> 2

    url2 = url_1
    r2 = act_req.get(url_1)
    print(r2.url)
    soup2 = BeautifulSoup(r2.text, 'html.parser')
    tag1 = soup2.findAll('div', {'class': 'ranavnode'})
    dom = []
    for x in tag1:
        temp = x.find('tr')
        dom.append(temp)
    data_orig2 = []

    for v in dom[1:]:
        data2 = {}

        chck2= v.find('a', {'class': 'navlabellink nvoffset nnormal'})

        if chck2 is None:
            chck2 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
            data['name'] = 'important'
        url_2 = urljoin(url2, chck2.get('href'))
        name_2 = chck2.text

        data2["name"] = name_2
        data2["url"] = url_2

        data_orig2.append(data2)

        # year - 3
        url3 = url_2
        r3 = act_req.get(url_2)
        print(r3.url)
        soup3 = BeautifulSoup(r3.text, 'html.parser')
        tag3 = soup3.findAll('div', {'class': 'inner'})
        om = []
        for x in tag3:
            temp = x.find('tr')
            om.append(temp)
        data_orig3 = []

        for v in om[2:]:
            data3 = {}

            chck3= v.find('a', {'class': 'navlabellink nvoffset nnormal'})

            if chck3 is None:
                chck3 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
                data['name'] = 'important'
            url_3 = urljoin(url3, chck3.get('href'))
            name_3 = chck3.text

            data3["name"] = name_3
            data3["url"] = url_3

            data_orig3.append(data3)

            # ABARTH --> 1996--> 1000 --> 	982cc L4		RSS Feed  - 4
            url4 = url_3
            r4 = act_req.get(url_3)
            soup4 = BeautifulSoup(r4.text, 'html.parser')
            tag4 = soup4.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
            omm = []
            for x in tag4:
                temp = x.find('tr')
                omm.append(temp)
            # RSS_url = ''
            for dta in omm:
                if 'href="/RSS' in str(dta):
                    RSS_url = urljoin(url4, dta.find('a', {'target': '_blank'})['href'])
                    print(RSS_url)
            data_orig4 = []
            for v in omm[3:]:
                data4 = {}

                chck4 = v.find('a', {'class': 'navlabellink nvoffset nnormal'})

                if chck4 is None:
                    chck4 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
                    data['name'] = 'important'
                url_4 = urljoin(url4, chck4.get('href'))
                name_4 = chck4.text
                for dta in omm:
                    if 'href="/RSS' in str(dta):
                        RSS_url = urljoin(url4, dta.find('a', {'target': '_blank'})['href'])

                data4["name"] = name_4
                data4["url"] = url_4
                data4["Really Simple Syndication"] = RSS_url
                data_orig4.append(data4)

                # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed --> Brake & Wheel Hub-5

                url5 = url_4
                r5 = act_req.get(url_4)
                print(r5.url)
                soup5 = BeautifulSoup(r5.text, 'html.parser')
                tag5 = soup5.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
                omm = []
                for x in tag5:
                    temp = x.find('tr')
                    omm.append(temp)
                data_orig5 = []

                for v in omm[4:]:
                    data5 = {}

                    chck5 = v.find('a', {'class': 'navlabellink nvoffset nnormal'})

                    if chck5 is None:
                        chck5 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
                        data5['name'] = 'important'
                    url_5 = urljoin(url5, chck5.get('href'))
                    name_5 = chck5.text

                    data5["name"] = name_5
                    data5["url"] = url_5

                    data_orig5.append(data5)

                    # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed --> Brake & Wheel Hub --> Brake Pad - 6

                    url6 = url_5
                    r6 = act_req.get(url_5)
                    print(r6.url)
                    soup6 = BeautifulSoup(r6.text, 'html.parser')
                    tag6 = soup6.find('div', id="treeroot[catalog]").findAll('div', {'class': 'ranavnode'})
                    omt = []
                    for x in tag6:
                        temp = x.find('tr')
                        omt.append(temp)
                    data_orig6 = []

                    for v in omt[5:]:
                        data6 = {}

                        chck6 = v.find('a', {'class': 'navlabellink nvoffset nnormal'})

                        if chck6 is None:
                            chck6 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
                        data6['name'] = 'important'
                        url_6 = urljoin(url6, chck6.get('href'))
                        name_6 = chck6.text

                        data6["name"] = name_6
                        data6["url"] = url_6

                        data_orig6.append(data6)

                        # ABARTH --> 1996--> 1000 -->  982cc L4 RSS Feed --> Brake & Wheel Hub --> Brake Pad --> INFO
                        # ->7
                        url7 = url_6
                        r7 = act_req.get(url_6)
                        print(r7.url)
                        soup7 = BeautifulSoup(r7.text, 'html.parser')
                        table_v = soup7.find('form', {'class': 'nobmp', 'method': 'post'}).findAll('div', {
                            'class': 'listing-text-row-moreinfo-truck'})

                        data_orig7 = []

                        for dta in table_v:
                            data = {}
                            d1 = d2 = "Null"
                            try:
                                d1 = dta.text.strip()
                            except:
                                pass
                            try:
                                d2 = dta.find('a')['href']
                            except:
                                pass
                            data.update({d1: d2})
                            data_orig7.append(data)

                            li = {"Make": name_1,
                                  "country": flags_1,
                                  "Year": name_2,
                                  "Model": name_3,
                                  "Part": name_4,
                                  "Product": name_5,
                                  "Really Simple Syndication_URL": RSS_url,
                                  "Sub_Product": name_6,
                                  "Product_Name_Info_Link": data_orig7}
                            print(li)
                            with open(filename, "a", encoding="utf-8") as f:
                                f.write(str(li))
# Out:
# https://www.rockauto.com/en/catalog/abarth
# https://www.rockauto.com/en/catalog/abarth
# https://www.rockauto.com/en/catalog/abarth,1969
# https://www.rockauto.com/RSS/subscribe.php?carcode=1438885
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,brake+&+wheel+hub
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,brake+&+wheel+hub,brake+pad,1684
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Brake & Wheel Hub', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Brake Pad', 'Product_Name_Info_Link': [{'RAYBESTOS MGD9M R-Line Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11751273&cc=1438885&pt=1684'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Brake & Wheel Hub', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Brake Pad', 'Product_Name_Info_Link': [{'RAYBESTOS MGD9M R-Line Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11751273&cc=1438885&pt=1684'}, {'RAYBESTOS PGD9M Element3 Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=298881&cc=1438885&pt=1684'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system,coolant+/+antifreeze,11393
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1438885&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1438885&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1438885&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1438885&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1438885&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1438885&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1438885&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1438885&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1438885&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1438885&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1438885&pt=11393'}, {'PRESTONE AF2100 Extended Life, Full Strength Concentrate; Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973389&cc=1438885&pt=11393'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,cooling+system,cooling+fan+control+module,12955
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Cooling Fan Control Module', 'Product_Name_Info_Link': [{'WVE 6H1518 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13048597&cc=1438885&pt=12955'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical,speed+sensor,10634
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Electrical', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Speed Sensor', 'Product_Name_Info_Link': [{'DELPHI SS11855 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11184369&cc=1438885&pt=10634'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical-bulb+&+socket
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical-bulb+&+socket,headlamp+socket,4056
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Electrical-Bulb & Socket', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Headlamp Socket', 'Product_Name_Info_Link': [{'WVE 1P1338 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8053332&cc=1438885&pt=4056'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical-connector
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,electrical-connector,ignition+condenser+/+capacitor+connector,15925
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Electrical-Connector', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Ignition Condenser / Capacitor Connector', 'Product_Name_Info_Link': [{'WVE 1P1840 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=3969264&cc=1438885&pt=15925'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine,balance+shaft+sprocket,5193
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Balance Shaft Sprocket', 'Product_Name_Info_Link': [{'PREFERRED COMPONENTS INC G57201 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12228097&cc=1438885&pt=5193'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine,connecting+rod+bearing,5212
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Connecting Rod Bearing', 'Product_Name_Info_Link': [{'MAHLE / CLEVITE CB1450P P Series (Tri-Metal); Pair Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12282021&cc=1438885&pt=5212'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine,oil+pan+gasket,5436
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Oil Pan Gasket', 'Product_Name_Info_Link': [{'VICTOR REINZ 711017600 Beaded Steel Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11477345&cc=1438885&pt=5436'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine,valve+spring+shim,5788
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Valve Spring Shim', 'Product_Name_Info_Link': [{'MELLING VSK46656T High Performance; Titanium Retainer; No Warranty Info': 'https://www.rockauto.com/en/moreinfo.php?pk=14048081&cc=1438885&pt=5788'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,engine,variable+valve+timing+(vvt)+sprocket,18586
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Variable Valve Timing (VVT) Sprocket', 'Product_Name_Info_Link': [{'AISIN VCB003 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=7168056&cc=1438885&pt=18586'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,ignition
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,ignition,ignition+coil,7060
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Ignition Coil', 'Product_Name_Info_Link': [{'WVE 5C1019 Used on most import products with 12 Volt system with Internal resistor; Universal 12 Volt Coil Info': 'https://www.rockauto.com/en/moreinfo.php?pk=930982&cc=1438885&pt=7060'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Ignition Coil', 'Product_Name_Info_Link': [{'WVE 5C1019 Used on most import products with 12 Volt system with Internal resistor; Universal 12 Volt Coil Info': 'https://www.rockauto.com/en/moreinfo.php?pk=930982&cc=1438885&pt=7060'}, {'DELPHI GN10698 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=9646644&cc=1438885&pt=7060'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,ignition,spark+plug,7212
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}, {'AUTOLITE APP63 Double Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55281&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}, {'AUTOLITE APP63 Double Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55281&cc=1438885&pt=7212'}, {'CHAMPION 7415 Double Platinum Power; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=5260962&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}, {'AUTOLITE APP63 Double Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55281&cc=1438885&pt=7212'}, {'CHAMPION 7415 Double Platinum Power; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=5260962&cc=1438885&pt=7212'}, {'SKP SP1041 Enhanced Tapered Ground Electrode w/ Platinum Chip Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11398265&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}, {'AUTOLITE APP63 Double Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55281&cc=1438885&pt=7212'}, {'CHAMPION 7415 Double Platinum Power; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=5260962&cc=1438885&pt=7212'}, {'SKP SP1041 Enhanced Tapered Ground Electrode w/ Platinum Chip Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11398265&cc=1438885&pt=7212'}, {'AUTOLITE XP63 Iridium XP; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=904934&cc=1438885&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1438885&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1438885&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1438885&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1438885&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'MOTORCRAFT SP402 Copper Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1110756&cc=1438885&pt=7212'}, {'AUTOLITE APP63 Double Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55281&cc=1438885&pt=7212'}, {'CHAMPION 7415 Double Platinum Power; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=5260962&cc=1438885&pt=7212'}, {'SKP SP1041 Enhanced Tapered Ground Electrode w/ Platinum Chip Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11398265&cc=1438885&pt=7212'}, {'AUTOLITE XP63 Iridium XP; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=904934&cc=1438885&pt=7212'}, {'CHAMPION 9804 Iridium; Pre-Set Gap: 0.03" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=960074&cc=1438885&pt=7212'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,wiper+&+washer
# https://www.rockauto.com/en/catalog/abarth,1969,1000,982cc+l4,1438885,wiper+&+washer,wiper+blade,8852
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}, {'TRICO 33130 Classic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4904673&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}, {'TRICO 33130 Classic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4904673&cc=1438885&pt=8852'}, {'ANCO 3013 Winter; Conventional Blade w/ Anti-Icing Boots; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532553&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}, {'TRICO 33130 Classic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4904673&cc=1438885&pt=8852'}, {'ANCO 3013 Winter; Conventional Blade w/ Anti-Icing Boots; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532553&cc=1438885&pt=8852'}, {'TRICO 35130 Ice; Beam Style; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=7001312&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}, {'TRICO 33130 Classic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4904673&cc=1438885&pt=8852'}, {'ANCO 3013 Winter; Conventional Blade w/ Anti-Icing Boots; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532553&cc=1438885&pt=8852'}, {'TRICO 35130 Ice; Beam Style; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=7001312&cc=1438885&pt=8852'}, {'TRICO 37131 Chill; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50764&cc=1438885&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1000', 'Part': '982cc L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1438885', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 14C13 14-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8322912&cc=1438885&pt=8852'}, {'TRICO 30130 30 Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=362128&cc=1438885&pt=8852'}, {'ANCO 3113 31-Series; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=993001&cc=1438885&pt=8852'}, {'TRICO 31130 View Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4005012&cc=1438885&pt=8852'}, {'TRICO 131 Exact Fit; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50717&cc=1438885&pt=8852'}, {'TRICO 33130 Classic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=4904673&cc=1438885&pt=8852'}, {'ANCO 3013 Winter; Conventional Blade w/ Anti-Icing Boots; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532553&cc=1438885&pt=8852'}, {'TRICO 35130 Ice; Beam Style; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=7001312&cc=1438885&pt=8852'}, {'TRICO 37131 Chill; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50764&cc=1438885&pt=8852'}, {'TRICO 18130 Flex; 13" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=7001304&cc=1438885&pt=8852'}]}
# https://www.rockauto.com/RSS/subscribe.php?carcode=1439131
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,cooling+system
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,cooling+system,coolant+/+antifreeze,11393
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1439131&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1439131&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1439131&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1439131&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1439131&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1439131&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1439131&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1439131&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1439131&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1439131&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1439131&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1439131&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1439131&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1439131&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1439131&pt=11393'}, {'PRESTONE AF2100 Extended Life, Full Strength Concentrate; Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973389&cc=1439131&pt=11393'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,cooling+system,cooling+fan+control+module,12955
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Cooling Fan Control Module', 'Product_Name_Info_Link': [{'WVE 6H1518 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13048597&cc=1439131&pt=12955'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,electrical-bulb+&+socket
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,electrical-bulb+&+socket,headlamp+socket,4056
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Electrical-Bulb & Socket', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Headlamp Socket', 'Product_Name_Info_Link': [{'WVE 1P1338 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8053332&cc=1439131&pt=4056'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,ignition
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,ignition,ignition+coil,7060
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Ignition Coil', 'Product_Name_Info_Link': [{'WVE 5C1019 Used on most import products with 12 Volt system with Internal resistor; Universal 12 Volt Coil Info': 'https://www.rockauto.com/en/moreinfo.php?pk=930982&cc=1439131&pt=7060'}]}
# https://www.rockauto.com/en/catalog/abarth,1969,1300,1.3l+l4,1439131,ignition,spark+plug,7212
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1439131&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1439131&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1439131&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1439131&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1439131&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1439131&pt=7212'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1969', 'Model': '1300', 'Part': '1.3L L4', 'Product': 'Ignition', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439131', 'Sub_Product': 'Spark Plug', 'Product_Name_Info_Link': [{'AUTOLITE AP63 Platinum; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=55241&cc=1439131&pt=7212'}, {'ACDELCO 4 Platinum Rapidfire®; Pre-Set Gap: 0.041" ($1 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}, {'AUTOLITE 63 Copper Resistor; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=54680&cc=1439131&pt=7212'}, {'CHAMPION 415 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=205550&cc=1439131&pt=7212'}, {'CHAMPION 300 Copper Plus; Pre-Set Gap: 0.032" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=317920&cc=1439131&pt=7212'}, {'ACDELCO R42XLS Professional; Conventional; Pre-Set Gap: 0.035" ($0.50 Rebate Available!) \xa0 Info': '/lang/en/promo.html#acdelcoplugs'}]}
# ...
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '2000', 'Part': '1.9L L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439381', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1439381&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '2000', 'Part': '1.9L L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439381', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1439381&pt=8852'}, {'TRICO 111 Exact Fit; 11" (280mm) 5mm Bayonet, 6/8mm Hook Type Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50714&cc=1439381&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '2000', 'Part': '1.9L L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439381', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1439381&pt=8852'}, {'TRICO 111 Exact Fit; 11" (280mm) 5mm Bayonet, 6/8mm Hook Type Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50714&cc=1439381&pt=8852'}, {'ANCO 3011 Winter; Conventional Blade w/ Anti-Icing Boots; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532586&cc=1439381&pt=8852'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '2000', 'Part': '1.9L L4', 'Product': 'Wiper & Washer', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1439381', 'Sub_Product': 'Wiper Blade', 'Product_Name_Info_Link': [{'ANCO 3111 31-Series; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532609&cc=1439381&pt=8852'}, {'TRICO 111 Exact Fit; 11" (280mm) 5mm Bayonet, 6/8mm Hook Type Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50714&cc=1439381&pt=8852'}, {'ANCO 3011 Winter; Conventional Blade w/ Anti-Icing Boots; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=532586&cc=1439381&pt=8852'}, {'TRICO 37111 Chill; 11" Info': 'https://www.rockauto.com/en/moreinfo.php?pk=50763&cc=1439381&pt=8852'}]}
# https://www.rockauto.com/RSS/subscribe.php?carcode=1492799
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,brake+&+wheel+hub
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,brake+&+wheel+hub,brake+pad,1684
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Brake & Wheel Hub', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Brake Pad', 'Product_Name_Info_Link': [{'RAYBESTOS MGD9M R-Line Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11751273&cc=1492799&pt=1684'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Brake & Wheel Hub', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Brake Pad', 'Product_Name_Info_Link': [{'RAYBESTOS MGD9M R-Line Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11751273&cc=1492799&pt=1684'}, {'RAYBESTOS PGD9M Element3 Metallic Info': 'https://www.rockauto.com/en/moreinfo.php?pk=298881&cc=1492799&pt=1684'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,cooling+system
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,cooling+system,coolant+/+antifreeze,11393
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1492799&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1492799&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1492799&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1492799&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1492799&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1492799&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1492799&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1492799&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1492799&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1492799&pt=11393'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Coolant / Antifreeze', 'Product_Name_Info_Link': [{'PRESTONE AF3300 Prime Conventional Green 50/50 1 Gallon; Prime®; Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973401&cc=1492799&pt=11393'}, {'FVP GREEN5050GAL Low Silicate Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527801&cc=1492799&pt=11393'}, {'PRESTONE AF555 Low Tox Antifreeze; LowTox® Blend; 1 Gallon; Green; IAT Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973409&cc=1492799&pt=11393'}, {'PRESTONE AF3100 Prime Extended Life All Makes All Models Antifreeze/Coolant; Prime® Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973397&cc=1492799&pt=11393'}, {'FVP MV5050GAL Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13527805&cc=1492799&pt=11393'}, {'PRESTONE AF2100 Extended Life, Full Strength Concentrate; Extended Life; All Makes / All Models; 1 Gallon Info': 'https://www.rockauto.com/en/moreinfo.php?pk=12973389&cc=1492799&pt=11393'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,cooling+system,cooling+fan+control+module,12955
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Cooling System', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Cooling Fan Control Module', 'Product_Name_Info_Link': [{'WVE 6H1518 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=13048597&cc=1492799&pt=12955'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical,starter+solenoid,4188
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Electrical', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Starter Solenoid', 'Product_Name_Info_Link': [{'STANDARD MOTOR PRODUCTS SS258 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=42724&cc=1492799&pt=4188'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical-bulb+&+socket
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical-bulb+&+socket,headlamp+socket,4056
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Electrical-Bulb & Socket', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Headlamp Socket', 'Product_Name_Info_Link': [{'WVE 1P1338 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=8053332&cc=1492799&pt=4056'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical-switch+&+relay
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,electrical-switch+&+relay,oil+pressure+sender+/+switch,4588
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Electrical-Switch & Relay', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Oil Pressure Sender / Switch', 'Product_Name_Info_Link': [{'STANDARD MOTOR PRODUCTS PS15T T-Series Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1006321&cc=1492799&pt=4588'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Electrical-Switch & Relay', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Oil Pressure Sender / Switch', 'Product_Name_Info_Link': [{'STANDARD MOTOR PRODUCTS PS15T T-Series Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1006321&cc=1492799&pt=4588'}, {'ACDELCO C8020 Professional Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1140335&cc=1492799&pt=4588'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Electrical-Switch & Relay', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Oil Pressure Sender / Switch', 'Product_Name_Info_Link': [{'STANDARD MOTOR PRODUCTS PS15T T-Series Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1006321&cc=1492799&pt=4588'}, {'ACDELCO C8020 Professional Info': 'https://www.rockauto.com/en/moreinfo.php?pk=1140335&cc=1492799&pt=4588'}, {'STANDARD MOTOR PRODUCTS PS15 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=44195&cc=1492799&pt=4588'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,engine
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,engine,conversion+/+lower+gasket+set,10424
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Conversion / Lower Gasket Set', 'Product_Name_Info_Link': [{'AJUSA 54009500 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11084524&cc=1492799&pt=10424'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,engine,crankshaft+seal,5604
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Crankshaft Seal', 'Product_Name_Info_Link': [{'AJUSA 15019000 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11072408&cc=1492799&pt=5604'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Crankshaft Seal', 'Product_Name_Info_Link': [{'AJUSA 15019000 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11072408&cc=1492799&pt=5604'}, {'AJUSA 15030900 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11072556&cc=1492799&pt=5604'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,engine,cylinder+head+bolt,5308
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Cylinder Head Bolt', 'Product_Name_Info_Link': [{'AJUSA 81010100 Set Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11089796&cc=1492799&pt=5308'}]}
# https://www.rockauto.com/en/catalog/abarth,1966,850,847cc+l4,1492799,engine,cylinder+head+gasket,5412
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Cylinder Head Gasket', 'Product_Name_Info_Link': [{'AJUSA 10072600 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11064448&cc=1492799&pt=5412'}]}
# {'Make': 'ABARTH', 'country': ['USA'], 'Year': '1966', 'Model': '850', 'Part': '847cc L4', 'Product': 'Engine', 'Really Simple Syndication_URL': 'https://www.rockauto.com/RSS/subscribe.php?carcode=1492799', 'Sub_Product': 'Cylinder Head Gasket', 'Product_Name_Info_Link': [{'AJUSA 10072600 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11064448&cc=1492799&pt=5412'}, {'AJUSA 10041500 Info': 'https://www.rockauto.com/en/moreinfo.php?pk=11064216&cc=1492799&pt=5412'}]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 186
#     184     chck6 = v.find('a', {'class': 'navlabellink nvoffset nimportant'})
#     185 data6['name'] = 'important'
# --> 186 url_6 = urljoin(url6, chck6.get('href'))
#     187 name_6 = chck6.text
#     189 data6["name"] = name_6
#
# AttributeError: 'NoneType' object has no attribute 'get'
